# %% [markdown]
# # 00 — Cost model (PRD §4a)
# Derive T1/T3 from real prices, freeze `docs/cost_model.md`. Do this BEFORE any pipeline run.

# %%
from redundancy.config import CostConstants
from redundancy.cost_model import derive_thresholds, sensitivity_table, write_doc

# Replace these with the real (frontier-normalized) prices, then re-run.
cost = CostConstants(c_cache=0.002, c_small=0.05, p_small=0.5, s_target=0.5)
print(derive_thresholds(cost))
for r in sensitivity_table(cost):
    print(r)
# write_doc(cost)  # uncomment to freeze docs/cost_model.md
