# %% [markdown]
# # 01 — Data exploration (PRD §7)
# Sanity-check WildChat first-turn extraction before pipelining. No outputs committed.

# %%
from redundancy.data import load_records

recs = load_records(2000, dataset='wildchat')
print(len(recs))
for r in recs[:5]:
    print(r.prompt[:200], '\n---')
