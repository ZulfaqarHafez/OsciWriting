# %% [markdown]
# # 04 — Results inspection (PRD §10)
# Interactive exploration of the latest run: headline numbers, cluster examples, judge transcripts, control gaps. Manual cluster sanity check (PRD §11 Day 5).

# %%
import json
from redundancy.config import RESULTS

run = (RESULTS / 'latest.txt').read_text().strip()
headline = json.loads((RESULTS / run / 'headline_numbers.json').read_text())
print(json.dumps(headline['decision'], indent=2))
print(json.dumps(headline.get('H5'), indent=2))
