# %% [markdown]
# # 03 — Pilot run (PRD §11 Day 2)
# Debug the pipeline end-to-end at N=5000 (no judge), then the N-stability acceptance test: if any headline number differs >15% relative between N=5000 and N=50000, escalate N (PRD §7).

# %%
from redundancy.pipeline import run

small = run(5000, 'wildchat', use_judge=False, seed=42)
# big = run(50000, 'wildchat', use_judge=False, seed=42)
# compare small vs big H1/H3/H4 within 15% relative -> N decision (PRD §7)
